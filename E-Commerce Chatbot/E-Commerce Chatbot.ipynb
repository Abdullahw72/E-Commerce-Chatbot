# %% [markdown]
# ## Import and Load data file

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
import random

words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('intents.json').read()
intents = json.loads(data_file)

# %% [markdown]
# ## Pre-process data

# %% [markdown]
# Here we iterate through the patterns and tokenize the sentence using nltk.word_tokenize() function and append each word in the words list. We also create a list of classes for our tags.

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:

        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %% [markdown]
# lemmatize each word and remove duplicate words from the list

# %%
# lemmatize, lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)

pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# 105 documents
# 22 classes ['cancel', 'confirm', 'delay', 'delivery', 'goodbye', 'greeting', 'items', 'mobile app', 'more', 'order status', 'payments', 'personal', 'profile info', 'reasons', 'refund', 'refund status', 'return', 'thanks', 'track', 'use voucher', 'user response', 'withdraw refunds']
# 145 unique lemmatized words ["'m", "'s", '.', 'a', 'about', 'accept', 'account', 'address', 'agent', 'am', 'an', 'any', 'anyone', 'app', 'are', 'available', 'be', 'become', 'but', 'buy', 'bye', 'call', 'can', 'cancel', 'cancelled', 'card', 'cash', 'change', 'common', 'completed', 'confirmation', 'confirmed', 'contact', 'credit', 'credited', 'customer', 'day', 'deducted', 'delay', 'delayed', 'delete', 'delivered', 'delivery', 'did', 'do', 'doe', 'doing', 'download', 'even', 'for', 'from', 'fund', 'get', 'good', 'goodbye', 'have', 'hello', 'help', 'helpful', 'helpline', 'hey', 'hi', 'how', 'i', 'im', 'information', 'is', 'it', 'item', 'kind', 'know', 'later', 'long', 'lot', 'mastercard', 'me', 'method', 'mobile', 'money', 'more', 'my', "n't", 'need', 'no', 'not', 'number', 'of', 'offer', 'okay', 'only', 'order', 'password', 'pay', 'payment', 'phone', 'please', 'processed', 'profile', 'reason', 'receive', 'received', 'refund', 'refunded', 'reset', 'return', 'returned', 'say', 'see', 'sell', 'seller', 'service', 'shipping', 'should', 'status', 'successfully', 'support', 'take', 'talk', 'tell', 'thank', 'thanks', 'that', 'the', 'there', 'this', 'thnks', 'though', 'thx', 'to', 'track', 'use', 'voucher', 'wa', 'wallet', 'want', 'what', 'when', 'which', 'why', 'will', 'with', 'withdraw', 'yet', 'you', 'your']

# %% [markdown]
# ## Create training and testing data

# %%
# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    
    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")
# Out:
# Training data created
# C:\Users\Leo\AppData\Local\Temp/ipykernel_9072/2451131480.py:24: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training = np.array(training)

# %% [markdown]
# ## Create Model

# %%
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)

print("model created")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:108: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# Epoch 1/200
# 21/21 [==============================] - 0s 900us/step - loss: 3.1247 - accuracy: 0.0667
# Epoch 2/200
# 21/21 [==============================] - 0s 800us/step - loss: 3.0044 - accuracy: 0.1238
# Epoch 3/200
# 21/21 [==============================] - 0s 750us/step - loss: 2.8556 - accuracy: 0.1619
# Epoch 4/200
# 21/21 [==============================] - 0s 946us/step - loss: 2.7712 - accuracy: 0.1905
# Epoch 5/200
# 21/21 [==============================] - 0s 800us/step - loss: 2.5731 - accuracy: 0.2667
# Epoch 6/200
# 21/21 [==============================] - 0s 800us/step - loss: 2.4891 - accuracy: 0.3048
# Epoch 7/200
# 21/21 [==============================] - 0s 800us/step - loss: 2.3459 - accuracy: 0.2952
# Epoch 8/200
# 21/21 [==============================] - 0s 750us/step - loss: 2.2398 - accuracy: 0.3429
# Epoch 9/200
# 21/21 [==============================] - 0s 750us/step - loss: 1.9440 - accuracy: 0.4381
# Epoch 10/200
# 21/21 [==============================] - 0s 800us/step - loss: 1.8847 - accuracy: 0.4762
# Epoch 11/200
# 21/21 [==============================] - 0s 750us/step - loss: 1.7756 - accuracy: 0.4762
# Epoch 12/200
# 21/21 [==============================] - 0s 800us/step - loss: 1.5412 - accuracy: 0.5714
# Epoch 13/200
# 21/21 [==============================] - 0s 850us/step - loss: 1.3341 - accuracy: 0.6857
# Epoch 14/200
# 21/21 [==============================] - 0s 850us/step - loss: 1.4207 - accuracy: 0.6095
# Epoch 15/200
# 21/21 [==============================] - 0s 850us/step - loss: 1.2258 - accuracy: 0.5714
# Epoch 16/200
# 21/21 [==============================] - 0s 800us/step - loss: 1.0095 - accuracy: 0.7429
# Epoch 17/200
# 21/21 [==============================] - 0s 850us/step - loss: 0.9162 - accuracy: 0.7333
# Epoch 18/200
# 21/21 [==============================] - 0s 850us/step - loss: 1.1002 - accuracy: 0.6762
# Epoch 19/200
# 21/21 [==============================] - 0s 850us/step - loss: 0.8550 - accuracy: 0.7524
# Epoch 20/200
# 21/21 [==============================] - 0s 900us/step - loss: 0.8753 - accuracy: 0.7524
# Epoch 21/200
# 21/21 [==============================] - 0s 850us/step - loss: 0.8027 - accuracy: 0.7143
# Epoch 22/200
# 21/21 [==============================] - 0s 750us/step - loss: 0.9106 - accuracy: 0.7333
# Epoch 23/200
# 21/21 [==============================] - 0s 850us/step - loss: 0.7034 - accuracy: 0.8000
# Epoch 24/200
# 21/21 [==============================] - 0s 750us/step - loss: 0.6726 - accuracy: 0.7714
# Epoch 25/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.6094 - accuracy: 0.8476
# Epoch 26/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.4671 - accuracy: 0.9048
# Epoch 27/200
# 21/21 [==============================] - 0s 900us/step - loss: 0.5515 - accuracy: 0.8095
# Epoch 28/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.5543 - accuracy: 0.8571
# Epoch 29/200
# 21/21 [==============================] - 0s 750us/step - loss: 0.4958 - accuracy: 0.8476
# Epoch 30/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.5875 - accuracy: 0.8095
# Epoch 31/200
# 21/21 [==============================] - 0s 900us/step - loss: 0.5755 - accuracy: 0.8571
# Epoch 32/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.4462 - accuracy: 0.8857
# Epoch 33/200
# 21/21 [==============================] - 0s 850us/step - loss: 0.4655 - accuracy: 0.8381
# Epoch 34/200
# 21/21 [==============================] - 0s 750us/step - loss: 0.3583 - accuracy: 0.8952
# Epoch 35/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.3949 - accuracy: 0.8857
# Epoch 36/200
# 21/21 [==============================] - 0s 750us/step - loss: 0.3992 - accuracy: 0.8762
# Epoch 37/200
# 21/21 [==============================] - 0s 850us/step - loss: 0.4851 - accuracy: 0.8190
# Epoch 38/200
# 21/21 [==============================] - 0s 850us/step - loss: 0.3169 - accuracy: 0.9333
# Epoch 39/200
# 21/21 [==============================] - 0s 850us/step - loss: 0.3773 - accuracy: 0.8571
# Epoch 40/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.3629 - accuracy: 0.8857
# Epoch 41/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.3668 - accuracy: 0.8667
# Epoch 42/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.3090 - accuracy: 0.9143
# Epoch 43/200
# 21/21 [==============================] - 0s 850us/step - loss: 0.3267 - accuracy: 0.8952
# Epoch 44/200
# 21/21 [==============================] - 0s 850us/step - loss: 0.3378 - accuracy: 0.8762
# Epoch 45/200
# 21/21 [==============================] - 0s 850us/step - loss: 0.3880 - accuracy: 0.8571
# Epoch 46/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.2984 - accuracy: 0.9143
# Epoch 47/200
# 21/21 [==============================] - 0s 850us/step - loss: 0.3131 - accuracy: 0.9143
# Epoch 48/200
# 21/21 [==============================] - 0s 850us/step - loss: 0.2876 - accuracy: 0.9143
# Epoch 49/200
# 21/21 [==============================] - 0s 850us/step - loss: 0.2758 - accuracy: 0.9143
# Epoch 50/200
# 21/21 [==============================] - 0s 750us/step - loss: 0.3296 - accuracy: 0.8667
# Epoch 51/200
# 21/21 [==============================] - 0s 750us/step - loss: 0.3664 - accuracy: 0.8762
# Epoch 52/200
# 21/21 [==============================] - 0s 750us/step - loss: 0.3550 - accuracy: 0.8571
# Epoch 53/200
# 21/21 [==============================] - 0s 750us/step - loss: 0.2344 - accuracy: 0.9524
# Epoch 54/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.2522 - accuracy: 0.9238
# Epoch 55/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.3133 - accuracy: 0.8762
# Epoch 56/200
# 21/21 [==============================] - 0s 750us/step - loss: 0.3016 - accuracy: 0.9333
# Epoch 57/200
# 21/21 [==============================] - 0s 750us/step - loss: 0.3227 - accuracy: 0.9048
# Epoch 58/200
# 21/21 [==============================] - 0s 850us/step - loss: 0.2612 - accuracy: 0.9238
# Epoch 59/200
# 21/21 [==============================] - 0s 700us/step - loss: 0.2341 - accuracy: 0.9333
# Epoch 60/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.2184 - accuracy: 0.9238
# Epoch 61/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.2380 - accuracy: 0.9429
# Epoch 62/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.2562 - accuracy: 0.9143
# Epoch 63/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.3073 - accuracy: 0.8952
# Epoch 64/200
# 21/21 [==============================] - 0s 750us/step - loss: 0.2906 - accuracy: 0.9238
# Epoch 65/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.2324 - accuracy: 0.9238
# Epoch 66/200
# 21/21 [==============================] - 0s 850us/step - loss: 0.1801 - accuracy: 0.9048
# Epoch 67/200
# 21/21 [==============================] - 0s 750us/step - loss: 0.2783 - accuracy: 0.9238
# Epoch 68/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.1883 - accuracy: 0.9238
# Epoch 69/200
# 21/21 [==============================] - 0s 700us/step - loss: 0.2442 - accuracy: 0.9238
# Epoch 70/200
# 21/21 [==============================] - 0s 850us/step - loss: 0.0946 - accuracy: 0.9714
# Epoch 71/200
# 21/21 [==============================] - 0s 750us/step - loss: 0.2344 - accuracy: 0.9143
# Epoch 72/200
# 21/21 [==============================] - 0s 700us/step - loss: 0.2970 - accuracy: 0.8952
# Epoch 73/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.2510 - accuracy: 0.9238
# Epoch 74/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.2652 - accuracy: 0.9238
# Epoch 75/200
# 21/21 [==============================] - 0s 950us/step - loss: 0.1796 - accuracy: 0.9429
# Epoch 76/200
# 21/21 [==============================] - 0s 850us/step - loss: 0.1552 - accuracy: 0.9333
# Epoch 77/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.1572 - accuracy: 0.9429
# Epoch 78/200
# 21/21 [==============================] - 0s 850us/step - loss: 0.1338 - accuracy: 0.9524
# Epoch 79/200
# 21/21 [==============================] - 0s 650us/step - loss: 0.1666 - accuracy: 0.9333
# Epoch 80/200
# 21/21 [==============================] - 0s 850us/step - loss: 0.1885 - accuracy: 0.9333
# Epoch 81/200
# 21/21 [==============================] - 0s 650us/step - loss: 0.2157 - accuracy: 0.9333
# Epoch 82/200
# 21/21 [==============================] - 0s 700us/step - loss: 0.1765 - accuracy: 0.9333
# Epoch 83/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.1956 - accuracy: 0.9238
# Epoch 84/200
# 21/21 [==============================] - 0s 700us/step - loss: 0.1525 - accuracy: 0.9524
# Epoch 85/200
# 21/21 [==============================] - 0s 650us/step - loss: 0.1794 - accuracy: 0.9143
# Epoch 86/200
# 21/21 [==============================] - 0s 700us/step - loss: 0.1359 - accuracy: 0.9429
# Epoch 87/200
# 21/21 [==============================] - 0s 750us/step - loss: 0.1798 - accuracy: 0.9429
# Epoch 88/200
# 21/21 [==============================] - 0s 850us/step - loss: 0.1060 - accuracy: 0.9619
# Epoch 89/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.1310 - accuracy: 0.9619
# Epoch 90/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.1075 - accuracy: 0.9714
# Epoch 91/200
# 21/21 [==============================] - 0s 950us/step - loss: 0.1778 - accuracy: 0.9333
# Epoch 92/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.1848 - accuracy: 0.9429
# Epoch 93/200
# 21/21 [==============================] - 0s 750us/step - loss: 0.1308 - accuracy: 0.9619
# Epoch 94/200
# 21/21 [==============================] - 0s 900us/step - loss: 0.2153 - accuracy: 0.9333
# Epoch 95/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.1122 - accuracy: 0.9714
# Epoch 96/200
# 21/21 [==============================] - 0s 700us/step - loss: 0.1856 - accuracy: 0.9333
# Epoch 97/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.1374 - accuracy: 0.9524
# Epoch 98/200
# 21/21 [==============================] - 0s 700us/step - loss: 0.1616 - accuracy: 0.9429
# Epoch 99/200
# 21/21 [==============================] - 0s 900us/step - loss: 0.1483 - accuracy: 0.9524
# Epoch 100/200
# 21/21 [==============================] - 0s 850us/step - loss: 0.1701 - accuracy: 0.9143
# Epoch 101/200
# 21/21 [==============================] - 0s 900us/step - loss: 0.1418 - accuracy: 0.9429
# Epoch 102/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.1999 - accuracy: 0.9143
# Epoch 103/200
# 21/21 [==============================] - 0s 850us/step - loss: 0.1423 - accuracy: 0.9429
# Epoch 104/200
# 21/21 [==============================] - 0s 950us/step - loss: 0.0939 - accuracy: 0.9619
# Epoch 105/200
# 21/21 [==============================] - 0s 900us/step - loss: 0.1540 - accuracy: 0.9619
# Epoch 106/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.1459 - accuracy: 0.9619
# Epoch 107/200
# 21/21 [==============================] - 0s 700us/step - loss: 0.0889 - accuracy: 0.9619
# Epoch 108/200
# 21/21 [==============================] - 0s 750us/step - loss: 0.1092 - accuracy: 0.9619
# Epoch 109/200
# 21/21 [==============================] - 0s 750us/step - loss: 0.1256 - accuracy: 0.9619
# Epoch 110/200
# 21/21 [==============================] - 0s 700us/step - loss: 0.1599 - accuracy: 0.9524
# Epoch 111/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.2091 - accuracy: 0.9048
# Epoch 112/200
# 21/21 [==============================] - 0s 700us/step - loss: 0.1005 - accuracy: 0.9714
# Epoch 113/200
# 21/21 [==============================] - 0s 650us/step - loss: 0.1151 - accuracy: 0.9714
# Epoch 114/200
# 21/21 [==============================] - 0s 700us/step - loss: 0.1257 - accuracy: 0.9714
# Epoch 115/200
# 21/21 [==============================] - 0s 700us/step - loss: 0.1164 - accuracy: 0.9429
# Epoch 116/200
# 21/21 [==============================] - 0s 650us/step - loss: 0.1289 - accuracy: 0.9714
# Epoch 117/200
# 21/21 [==============================] - 0s 700us/step - loss: 0.1305 - accuracy: 0.9429
# Epoch 118/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.0798 - accuracy: 0.9714
# Epoch 119/200
# 21/21 [==============================] - 0s 700us/step - loss: 0.1280 - accuracy: 0.9619
# Epoch 120/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.1785 - accuracy: 0.9524
# Epoch 121/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.1389 - accuracy: 0.9619
# Epoch 122/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.1438 - accuracy: 0.9714
# Epoch 123/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.1513 - accuracy: 0.9333
# Epoch 124/200
# 21/21 [==============================] - 0s 850us/step - loss: 0.1269 - accuracy: 0.9524
# Epoch 125/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.1549 - accuracy: 0.9238
# Epoch 126/200
# 21/21 [==============================] - 0s 700us/step - loss: 0.1430 - accuracy: 0.9619
# Epoch 127/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.1622 - accuracy: 0.9429
# Epoch 128/200
# 21/21 [==============================] - 0s 700us/step - loss: 0.0861 - accuracy: 0.9714
# Epoch 129/200
# 21/21 [==============================] - 0s 700us/step - loss: 0.1245 - accuracy: 0.9619
# Epoch 130/200
# 21/21 [==============================] - 0s 700us/step - loss: 0.1124 - accuracy: 0.9524
# Epoch 131/200
# 21/21 [==============================] - 0s 700us/step - loss: 0.1285 - accuracy: 0.9524
# Epoch 132/200
# 21/21 [==============================] - 0s 650us/step - loss: 0.1092 - accuracy: 0.9714
# Epoch 133/200
# 21/21 [==============================] - 0s 650us/step - loss: 0.0773 - accuracy: 0.9810
# Epoch 134/200
# 21/21 [==============================] - 0s 650us/step - loss: 0.1482 - accuracy: 0.9238
# Epoch 135/200
# 21/21 [==============================] - 0s 650us/step - loss: 0.1449 - accuracy: 0.9524
# Epoch 136/200
# 21/21 [==============================] - 0s 700us/step - loss: 0.1518 - accuracy: 0.9238
# Epoch 137/200
# 21/21 [==============================] - 0s 650us/step - loss: 0.1154 - accuracy: 0.9524
# Epoch 138/200
# 21/21 [==============================] - 0s 700us/step - loss: 0.1004 - accuracy: 0.9619
# Epoch 139/200
# 21/21 [==============================] - 0s 650us/step - loss: 0.1189 - accuracy: 0.9905
# Epoch 140/200
# 21/21 [==============================] - 0s 650us/step - loss: 0.1158 - accuracy: 0.9619
# Epoch 141/200
# 21/21 [==============================] - 0s 650us/step - loss: 0.0751 - accuracy: 0.9714
# Epoch 142/200
# 21/21 [==============================] - 0s 650us/step - loss: 0.1342 - accuracy: 0.9524
# Epoch 143/200
# 21/21 [==============================] - 0s 650us/step - loss: 0.1242 - accuracy: 0.9524
# Epoch 144/200
# 21/21 [==============================] - 0s 700us/step - loss: 0.1205 - accuracy: 0.9619
# Epoch 145/200
# 21/21 [==============================] - 0s 750us/step - loss: 0.0955 - accuracy: 0.9714
# Epoch 146/200
# 21/21 [==============================] - 0s 750us/step - loss: 0.1249 - accuracy: 0.9333
# Epoch 147/200
# 21/21 [==============================] - 0s 650us/step - loss: 0.1216 - accuracy: 0.9429
# Epoch 148/200
# 21/21 [==============================] - 0s 700us/step - loss: 0.1047 - accuracy: 0.9619
# Epoch 149/200
# 21/21 [==============================] - 0s 700us/step - loss: 0.1578 - accuracy: 0.9333
# Epoch 150/200
# 21/21 [==============================] - 0s 700us/step - loss: 0.0996 - accuracy: 0.9714
# Epoch 151/200
# 21/21 [==============================] - 0s 700us/step - loss: 0.0790 - accuracy: 0.9810
# Epoch 152/200
# 21/21 [==============================] - 0s 750us/step - loss: 0.1604 - accuracy: 0.9524
# Epoch 153/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.1013 - accuracy: 0.9714
# Epoch 154/200
# 21/21 [==============================] - 0s 700us/step - loss: 0.0961 - accuracy: 0.9619
# Epoch 155/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.0971 - accuracy: 0.9810
# Epoch 156/200
# 21/21 [==============================] - 0s 700us/step - loss: 0.1329 - accuracy: 0.9524
# Epoch 157/200
# 21/21 [==============================] - 0s 700us/step - loss: 0.0804 - accuracy: 0.9714
# Epoch 158/200
# 21/21 [==============================] - 0s 850us/step - loss: 0.0687 - accuracy: 0.9619
# Epoch 159/200
# 21/21 [==============================] - 0s 750us/step - loss: 0.1178 - accuracy: 0.9429
# Epoch 160/200
# 21/21 [==============================] - 0s 850us/step - loss: 0.0753 - accuracy: 0.9714
# Epoch 161/200
# 21/21 [==============================] - 0s 750us/step - loss: 0.1312 - accuracy: 0.9619
# Epoch 162/200
# 21/21 [==============================] - 0s 750us/step - loss: 0.0849 - accuracy: 0.9714
# Epoch 163/200
# 21/21 [==============================] - 0s 700us/step - loss: 0.1016 - accuracy: 0.9810
# Epoch 164/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.1258 - accuracy: 0.9429
# Epoch 165/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.0546 - accuracy: 0.9905
# Epoch 166/200
# 21/21 [==============================] - 0s 950us/step - loss: 0.0773 - accuracy: 0.9714
# Epoch 167/200
# 21/21 [==============================] - 0s 900us/step - loss: 0.1017 - accuracy: 0.9524
# Epoch 168/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.0866 - accuracy: 0.9714
# Epoch 169/200
# 21/21 [==============================] - 0s 900us/step - loss: 0.0761 - accuracy: 0.9714
# Epoch 170/200
# 21/21 [==============================] - 0s 750us/step - loss: 0.1471 - accuracy: 0.9619
# Epoch 171/200
# 21/21 [==============================] - 0s 750us/step - loss: 0.0746 - accuracy: 0.9714
# Epoch 172/200
# 21/21 [==============================] - 0s 700us/step - loss: 0.1758 - accuracy: 0.9429
# Epoch 173/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.1300 - accuracy: 0.9429
# Epoch 174/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.0991 - accuracy: 0.9714
# Epoch 175/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.0920 - accuracy: 0.9810
# Epoch 176/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.0607 - accuracy: 0.9810
# Epoch 177/200
# 21/21 [==============================] - 0s 850us/step - loss: 0.1217 - accuracy: 0.9619
# Epoch 178/200
# 21/21 [==============================] - 0s 750us/step - loss: 0.1094 - accuracy: 0.9619
# Epoch 179/200
# 21/21 [==============================] - 0s 750us/step - loss: 0.0648 - accuracy: 1.0000
# Epoch 180/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.0901 - accuracy: 0.9619
# Epoch 181/200
# 21/21 [==============================] - 0s 750us/step - loss: 0.0847 - accuracy: 0.9714
# Epoch 182/200
# 21/21 [==============================] - 0s 900us/step - loss: 0.1334 - accuracy: 0.9333
# Epoch 183/200
# 21/21 [==============================] - 0s 900us/step - loss: 0.1046 - accuracy: 0.9619
# Epoch 184/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.0858 - accuracy: 0.9524
# Epoch 185/200
# 21/21 [==============================] - 0s 850us/step - loss: 0.0957 - accuracy: 0.9524
# Epoch 186/200
# 21/21 [==============================] - 0s 750us/step - loss: 0.0729 - accuracy: 0.9714
# Epoch 187/200
# 21/21 [==============================] - 0s 700us/step - loss: 0.0940 - accuracy: 0.9619
# Epoch 188/200
# 21/21 [==============================] - 0s 850us/step - loss: 0.0674 - accuracy: 0.9714
# Epoch 189/200
# 21/21 [==============================] - 0s 850us/step - loss: 0.0590 - accuracy: 0.9810
# Epoch 190/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.0885 - accuracy: 0.9714
# Epoch 191/200
# 21/21 [==============================] - 0s 750us/step - loss: 0.0715 - accuracy: 0.9714
# Epoch 192/200
# 21/21 [==============================] - 0s 700us/step - loss: 0.0830 - accuracy: 0.9619
# Epoch 193/200
# 21/21 [==============================] - 0s 900us/step - loss: 0.0722 - accuracy: 0.9714
# Epoch 194/200
# 21/21 [==============================] - 0s 850us/step - loss: 0.0987 - accuracy: 0.9429
# Epoch 195/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.0858 - accuracy: 0.9619
# Epoch 196/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.0700 - accuracy: 0.9524
# Epoch 197/200
# 21/21 [==============================] - 0s 750us/step - loss: 0.1497 - accuracy: 0.9333
# Epoch 198/200
# 21/21 [==============================] - 0s 900us/step - loss: 0.1050 - accuracy: 0.9524
# Epoch 199/200
# 21/21 [==============================] - 0s 750us/step - loss: 0.0450 - accuracy: 0.9905
# Epoch 200/200
# 21/21 [==============================] - 0s 800us/step - loss: 0.0706 - accuracy: 0.9714
# model created

# %%
from keras.models import load_model
model = load_model('chatbot_model.h5')
import json
import random
intents = json.loads(open('intents.json').read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))

# %%
def clean_up_sentence(sentence):
    # tokenize the pattern - split words into array
    sentence_words = nltk.word_tokenize(sentence)
    # stem each word - create short form for word
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words
# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence

# %%
def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words) 
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s: 
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

# %%
def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

# %%
def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result

# %%
def chatbot_response(text):
    ints = predict_class(text, model)
    res = getResponse(ints, intents)
    return res

# %% [markdown]
# ## GUI Interface

# %%
import tkinter
from tkinter import *

BG_GRAY = "#ABB2B9"
BG_COLOR = "#c5f0e3"
TEXT_COLOR = "#000000"

# BG_GRAY = "#ABB2B9"
# BG_COLOR = "#1c172a"
# TEXT_COLOR = "#ffffff"


FONT = "Helvetica 14"
FONT_BOLD = "Helvetica 13 bold"


def send(event):
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)
    if msg != '':
        ChatLog.config(state=NORMAL)
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#000000", font=("Verdana", 12 ))

        res = chatbot_response(msg)
        ChatLog.insert(END, "Bot: " + res + '\n\n')

        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)
        
        
base = Tk()
base.title("E-Commerce Chatbot")
base.resizable(width=FALSE, height=FALSE)
base.configure(width=800, height=800, bg=BG_COLOR)


#Create Chat window
ChatLog = Text(base, bd=0, bg=BG_COLOR, fg=TEXT_COLOR, font=FONT_BOLD)
ChatLog.config(state=DISABLED)

head_label = Label(base, bg=BG_COLOR, fg=TEXT_COLOR, text="Welcome to E-Commerce Chatbot", font=FONT_BOLD, pady=10)
head_label.place(relwidth=1)

line = Label(base, width=450, bg=BG_GRAY)


#Bind scrollbar to Chat window
scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
ChatLog['yscrollcommand'] = scrollbar.set
ChatLog.focus()

#Create Button to send message
SendButton = Button(base, font=("Verdana", 12,'bold'), text="Send", width="12", height=15,
                    bd=0, bg="#ed9061", activebackground="#3c9d9b",fg='#ffffff',
                    command=lambda: send)

#Create the box to enter message
EntryBox = Text(base, bg="white",width="29", height="5", font="Arial", background="#dddddd")
EntryBox.focus()
EntryBox.bind("<Return>", send)
#EntryBox.bind("<Return>", send)

# bottom label
# bottom_label = Label(base, bg=BG_GRAY, height=80)
# bottom_label.place(relwidth=1, rely=0.825)
        
# message entry box
#EntryBox = Entry(bottom_label, fg=TEXT_COLOR, font=FONT)
# msg_entry.place(relwidth=0.74, relheight=0.06, rely=0.008, |relx=0.011)
# msg_entry.focus()


#Place all components on the screen
# scrollbar.place(relheight=1, relx=0.974)
# ChatLog.place(relheight=1, width=1)
# EntryBox.place(relwidth=0.74, relheight=0.06, rely=0.008, relx=0.011)
# SendButton.place(relx=0.77, rely=0.008, relheight=0.06, relwidth=0.20)\

scrollbar.place(x=775,y=6, height=800)
line.place(x=0,y=35, height=1, width=770)
ChatLog.place(x=5,y=40, height=700, width=770)
EntryBox.place(x=0, y=740, height=60, width=600)
SendButton.place(x=600, y=740, height=60, width=175)

# %%
base.mainloop()
# Out:
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
